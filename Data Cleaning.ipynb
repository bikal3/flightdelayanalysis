# %%
import pandas as pd
import glob

# %%
dtype_dict = {
    11: str,
    13: str,
    57: str,
    78: str,
    85: str,
    86: str,
    93: str
}
#Combinining All the dataset of 2022 in one csv.
# Folder path
folder_path = "Dataset/2022/"

# File extension
file_extension = "*.csv"

# Retrieve file paths
file_paths = glob.glob(folder_path + file_extension)

# Initialize an empty list to store the datasets
datasets = []

# Read and append each CSV file to the datasets list
for file_path in file_paths:
    try:
        dataset = pd.read_csv(file_path,dtype=dtype_dict)
        datasets.append(dataset)
    except pd.errors.EmptyDataError:
        print(f"Empty CSV file: {file_path}")

# Check if any datasets are found
if len(datasets) == 0:
    print("No datasets found.")

# Concatenate all datasets
dataset_2022 = pd.concat(datasets,ignore_index=True)

# Print the combined dataset
dataset_2022.head(10)
# Out:
# /var/folders/ns/41ddq7k52x11_1f3_004md3h0000gn/T/ipykernel_64635/2396658415.py:26: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(file_path,dtype=dtype_dict)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2022        2      6          27          1  2022-06-27
# 1  2022        2      6          28          2  2022-06-28
# 2  2022        2      6          29          3  2022-06-29
# 3  2022        2      6          30          4  2022-06-30
# 4  2022        2      6           1          3  2022-06-01
# 5  2022        2      6           2          4  2022-06-02
# 6  2022        2      6           3          5  2022-06-03
# 7  2022        2      6           4          6  2022-06-04
# 8  2022        2      6           5          7  2022-06-05
# 9  2022        2      6           6          1  2022-06-06
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# ...

# %%
dtype_dict = {
    11: str,
    13: str,
    57: str,
    78: str,
    85: str,
    86: str,
    93: str
}
#Combinining All the dataset of 2022 in one csv.
# Folder path
folder_path = "Dataset/2021/"

# File extension
file_extension = "*.csv"

# Retrieve file paths
file_paths = glob.glob(folder_path + file_extension)

# Initialize an empty list to store the datasets
datasets = []

# Read and append each CSV file to the datasets list
for file_path in file_paths:
    try:
        dataset = pd.read_csv(file_path,dtype=dtype_dict)
        datasets.append(dataset)
    except pd.errors.EmptyDataError:
        print(f"Empty CSV file: {file_path}")

# Check if any datasets are found
if len(datasets) == 0:
    print("No datasets found.")

# Concatenate all datasets
dataset_2021 = pd.concat(datasets,ignore_index=True)

# Print the combined dataset
dataset_2021.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2021        2      6           1          2  2021-06-01
# 1  2021        2      6           1          2  2021-06-01
# 2  2021        2      6           1          2  2021-06-01
# 3  2021        2      6           1          2  2021-06-01
# 4  2021        2      6           1          2  2021-06-01
# 5  2021        2      6           1          2  2021-06-01
# 6  2021        2      6           1          2  2021-06-01
# 7  2021        2      6           1          2  2021-06-01
# 8  2021        2      6           1          2  2021-06-01
# 9  2021        2      6           1          2  2021-06-01
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        WN                                      WN
# 1                        WN                                      WN
# 2                        WN                                      WN
# ...

# %%
dtype_dict = {
    11: str,
    13: str,
    57: str,
    78: str,
    85: str,
    86: str,
    93: str
}
#Combinining All the dataset of 2022 in one csv.
# Folder path
folder_path = "Dataset/2020/"

# File extension
file_extension = "*.csv"

# Retrieve file paths
file_paths = glob.glob(folder_path + file_extension)

# Initialize an empty list to store the datasets
datasets = []

# Read and append each CSV file to the datasets list
for file_path in file_paths:
    try:
        dataset = pd.read_csv(file_path,dtype=dtype_dict)
        datasets.append(dataset)
    except pd.errors.EmptyDataError:
        print(f"Empty CSV file: {file_path}")

# Check if any datasets are found
if len(datasets) == 0:
    print("No datasets found.")

# Concatenate all datasets
dataset_2020 = pd.concat(datasets,ignore_index=True)

# Print the combined dataset
dataset_2020.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2020        2      6          13          6  2020-06-13
# 1  2020        2      6          13          6  2020-06-13
# 2  2020        2      6          13          6  2020-06-13
# 3  2020        2      6          13          6  2020-06-13
# 4  2020        2      6          13          6  2020-06-13
# 5  2020        2      6          13          6  2020-06-13
# 6  2020        2      6          13          6  2020-06-13
# 7  2020        2      6          13          6  2020-06-13
# 8  2020        2      6          13          6  2020-06-13
# 9  2020        2      6          13          6  2020-06-13
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AS                                      AS
# 1                        AS                                      AS
# 2                        AS                                      AS
# ...

# %%
dtype_dict = {
    11: str,
    13: str,
    57: str,
    78: str,
    85: str,
    86: str,
    93: str
}
#Combinining All the dataset of 2022 in one csv.
# Folder path
folder_path = "Dataset/2019/"

# File extension
file_extension = "*.csv"

# Retrieve file paths
file_paths = glob.glob(folder_path + file_extension)

# Initialize an empty list to store the datasets
datasets = []

# Read and append each CSV file to the datasets list
for file_path in file_paths:
    try:
        dataset = pd.read_csv(file_path,dtype=dtype_dict)
        datasets.append(dataset)
    except pd.errors.EmptyDataError:
        print(f"Empty CSV file: {file_path}")

# Check if any datasets are found
if len(datasets) == 0:
    print("No datasets found.")

# Concatenate all datasets
dataset_2019 = pd.concat(datasets,ignore_index=True)

# Print the combined dataset
dataset_2019.head(10)
# Out:
# /var/folders/ns/41ddq7k52x11_1f3_004md3h0000gn/T/ipykernel_64635/1170844568.py:26: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(file_path,dtype=dtype_dict)
# /var/folders/ns/41ddq7k52x11_1f3_004md3h0000gn/T/ipykernel_64635/1170844568.py:26: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(file_path,dtype=dtype_dict)
# /var/folders/ns/41ddq7k52x11_1f3_004md3h0000gn/T/ipykernel_64635/1170844568.py:26: DtypeWarning: Columns (94,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(file_path,dtype=dtype_dict)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2019        2      6           1          6  2019-06-01
# 1  2019        2      6           1          6  2019-06-01
# 2  2019        2      6           1          6  2019-06-01
# ...

# %%
dtype_dict = {
    11: str,
    13: str,
    57: str,
    78: str,
    85: str,
    86: str,
    93: str
}
#Combinining All the dataset of 2022 in one csv.
# Folder path
folder_path = "Dataset/2018/"

# File extension
file_extension = "*.csv"

# Retrieve file paths
file_paths = glob.glob(folder_path + file_extension)

# Initialize an empty list to store the datasets
datasets = []

# Read and append each CSV file to the datasets list
for file_path in file_paths:
    try:
        dataset = pd.read_csv(file_path,encoding='latin1',dtype=dtype_dict)
        datasets.append(dataset)
    except pd.errors.EmptyDataError:
        print(f"Empty CSV file: {file_path}")

# Check if any datasets are found
if len(datasets) == 0:
    print("No datasets found.")

# Concatenate all datasets
dataset_2018 = pd.concat(datasets,ignore_index=True)

# Print the combined dataset
dataset_2018.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2018        2      6          28          4  2018-06-28
# 1  2018        2      6          29          5  2018-06-29
# 2  2018        2      6          30          6  2018-06-30
# 3  2018        2      6           1          5  2018-06-01
# 4  2018        2      6           2          6  2018-06-02
# 5  2018        2      6           3          7  2018-06-03
# 6  2018        2      6           4          1  2018-06-04
# 7  2018        2      6           5          2  2018-06-05
# 8  2018        2      6           6          3  2018-06-06
# 9  2018        2      6           7          4  2018-06-07
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        AA                                      AA
# 1                        AA                                      AA
# 2                        AA                                      AA
# ...

# %%
# Combine the all 5 datasets
dataset = pd.concat([dataset_2018, dataset_2019, dataset_2020,dataset_2021,dataset_2022], ignore_index=True)
dataset
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         2018        2      6          28          4  2018-06-28
# 1         2018        2      6          29          5  2018-06-29
# 2         2018        2      6          30          6  2018-06-30
# 3         2018        2      6           1          5  2018-06-01
# 4         2018        2      6           2          6  2018-06-02
# ...        ...      ...    ...         ...        ...         ...
# 33638827  2022        3      8          10          3  2022-08-10
# 33638828  2022        3      8          16          2  2022-08-16
# 33638829  2022        3      8          17          3  2022-08-17
# 33638830  2022        3      8          18          4  2022-08-18
# 33638831  2022        3      8          19          5  2022-08-19
#
#          Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                               AA                                      AA
# ...

# %%
dataset.to_csv("UncleanDataset.csv")

# %%
column_names = dataset.columns
print("Column Names:")
for column_name in column_names:
    print(column_name)
# Out:
# Column Names:
# Year
# Quarter
# Month
# DayofMonth
# DayOfWeek
# FlightDate
# Marketing_Airline_Network
# Operated_or_Branded_Code_Share_Partners
# DOT_ID_Marketing_Airline
# IATA_Code_Marketing_Airline
# Flight_Number_Marketing_Airline
# Originally_Scheduled_Code_Share_Airline
# DOT_ID_Originally_Scheduled_Code_Share_Airline
# IATA_Code_Originally_Scheduled_Code_Share_Airline
# Flight_Num_Originally_Scheduled_Code_Share_Airline
# Operating_Airline
# DOT_ID_Operating_Airline
# IATA_Code_Operating_Airline
# Tail_Number
# Flight_Number_Operating_Airline
# OriginAirportID
# OriginAirportSeqID
# OriginCityMarketID
# Origin
# OriginCityName
# OriginState
# OriginStateFips
# OriginStateName
# OriginWac
# DestAirportID
# DestAirportSeqID
# DestCityMarketID
# Dest
# DestCityName
# DestState
# DestStateFips
# DestStateName
# DestWac
# CRSDepTime
# DepTime
# DepDelay
# DepDelayMinutes
# DepDel15
# DepartureDelayGroups
# DepTimeBlk
# TaxiOut
# WheelsOff
# WheelsOn
# TaxiIn
# CRSArrTime
# ...

# %%
# Replace with the actual column names you want to remove
columns_to_remove = [
"DivAirportLandings",
"DivReachedDest",
"DivActualElapsedTime",
"DivArrDelay",
"DivDistance",
"Div1Airport",
"Div1AirportID",
"Div1AirportSeqID",
"Div1WheelsOn",
"Div1TotalGTime",
"Div1LongestGTime",
"Div1WheelsOff",
"Div1TailNum",
"Div2Airport",
"Div2AirportID",
"Div2AirportSeqID",
"Div2WheelsOn",
"Div2TotalGTime",
"Div2LongestGTime",
"Div2WheelsOff",
"Div2TailNum",
"Div3Airport",
"Div3AirportID",
"Div3AirportSeqID",
"Div3WheelsOn",
"Div3TotalGTime",
"Div3LongestGTime",
"Div3WheelsOff",
"Div3TailNum",
"Div4Airport",
"Div4AirportID",
"Div4AirportSeqID",
"Div4WheelsOn",
"Div4TotalGTime",
"Div4LongestGTime",
"Div4WheelsOff",
"Div4TailNum",
"Div5Airport",
"Div5AirportID",
"Div5AirportSeqID",
"Div5WheelsOn",
"Div5TotalGTime",
"Div5LongestGTime",
"Div5WheelsOff",
"Div5TailNum",
"Duplicate",
"Unnamed: 119"    
]

# %%
dataset = dataset.drop(columns=columns_to_remove)
dataset
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         2018        2      6          28          4  2018-06-28
# 1         2018        2      6          29          5  2018-06-29
# 2         2018        2      6          30          6  2018-06-30
# 3         2018        2      6           1          5  2018-06-01
# 4         2018        2      6           2          6  2018-06-02
# ...        ...      ...    ...         ...        ...         ...
# 33638827  2022        3      8          10          3  2022-08-10
# 33638828  2022        3      8          16          2  2022-08-16
# 33638829  2022        3      8          17          3  2022-08-17
# 33638830  2022        3      8          18          4  2022-08-18
# 33638831  2022        3      8          19          5  2022-08-19
#
#          Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                               AA                                      AA
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33638832 entries, 0 to 33638831
# Data columns (total 73 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   Year                                                int64
#  1   Quarter                                             int64
#  2   Month                                               int64
#  3   DayofMonth                                          int64
#  4   DayOfWeek                                           int64
#  5   FlightDate                                          object
#  6   Marketing_Airline_Network                           object
#  7   Operated_or_Branded_Code_Share_Partners             object
#  8   DOT_ID_Marketing_Airline                            float64
#  9   IATA_Code_Marketing_Airline                         object
#  10  Flight_Number_Marketing_Airline                     int64
# ...

# %%
column_names = dataset.columns
print("Column Names:")
for column_name in column_names:
    print(column_name)
# Out:
# Column Names:
# Year
# Quarter
# Month
# DayofMonth
# DayOfWeek
# FlightDate
# Marketing_Airline_Network
# Operated_or_Branded_Code_Share_Partners
# DOT_ID_Marketing_Airline
# IATA_Code_Marketing_Airline
# Flight_Number_Marketing_Airline
# Originally_Scheduled_Code_Share_Airline
# DOT_ID_Originally_Scheduled_Code_Share_Airline
# IATA_Code_Originally_Scheduled_Code_Share_Airline
# Flight_Num_Originally_Scheduled_Code_Share_Airline
# Operating_Airline
# DOT_ID_Operating_Airline
# IATA_Code_Operating_Airline
# Tail_Number
# Flight_Number_Operating_Airline
# OriginAirportID
# OriginAirportSeqID
# OriginCityMarketID
# Origin
# OriginCityName
# OriginState
# OriginStateFips
# OriginStateName
# OriginWac
# DestAirportID
# DestAirportSeqID
# DestCityMarketID
# Dest
# DestCityName
# DestState
# DestStateFips
# DestStateName
# DestWac
# CRSDepTime
# DepTime
# DepDelay
# DepDelayMinutes
# DepDel15
# DepartureDelayGroups
# DepTimeBlk
# TaxiOut
# WheelsOff
# WheelsOn
# TaxiIn
# CRSArrTime
# ...

# %%
columns_to_remove = [
'Marketing_Airline_Network',
'Operated_or_Branded_Code_Share_Partners',
'DOT_ID_Marketing_Airline',
'IATA_Code_Marketing_Airline',
'Flight_Number_Marketing_Airline',
'Originally_Scheduled_Code_Share_Airline',
'DOT_ID_Originally_Scheduled_Code_Share_Airline',
'IATA_Code_Originally_Scheduled_Code_Share_Airline',
'Flight_Num_Originally_Scheduled_Code_Share_Airline',
'OriginAirportSeqID',
'OriginCityMarketID',
'OriginWac',
'DestAirportSeqID',
'DestCityMarketID',
'DepTimeBlk',
'ArrTimeBlk'
]

# %%
dataset = dataset.drop(columns=columns_to_remove)
dataset.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Operating_Airline   \
# 0  2018        2      6          28          4  2018-06-28                 AA
# 1  2018        2      6          29          5  2018-06-29                 AA
# 2  2018        2      6          30          6  2018-06-30                 AA
# 3  2018        2      6           1          5  2018-06-01                 AA
# 4  2018        2      6           2          6  2018-06-02                 AA
# 5  2018        2      6           3          7  2018-06-03                 AA
# 6  2018        2      6           4          1  2018-06-04                 AA
# 7  2018        2      6           5          2  2018-06-05                 AA
# 8  2018        2      6           6          3  2018-06-06                 AA
# 9  2018        2      6           7          4  2018-06-07                 AA
#
#    DOT_ID_Operating_Airline IATA_Code_Operating_Airline Tail_Number  ...  \
# ...

# %%
dataset.to_csv("halfcleanDataset.csv")

# %%
import pandas as pd

# Assuming you have a DataFrame called 'dataset'
# Replace 'dataset' with the name of your DataFrame

# Set the random seed for reproducibility (optional)
random_seed = 42
# You can change 'random_seed' to any integer for different random samples

# Take a random 5% sample of the data
sampled_dataset = dataset.sample(frac=0.05, random_state=random_seed)

# Print the sampled dataset
sampled_dataset
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 25697209  2021        3      9          18          6  2021-09-18
# 27556637  2022        3      7           4          1  2022-07-04
# 9172350   2019        2      5          21          2  2019-05-21
# 14833569  2019        3      8          28          3  2019-08-28
# 32240106  2022        4     12           2          5  2022-12-02
# ...        ...      ...    ...         ...        ...         ...
# 16656515  2020        1      1          10          5  2020-01-10
# 30777177  2022        4     10           8          6  2022-10-08
# 15554844  2020        3      7          31          5  2020-07-31
# 19753557  2020        3      9          20          7  2020-09-20
# 29244771  2022        1      1           9          7  2022-01-09
#
#          Operating_Airline   DOT_ID_Operating_Airline  \
# 25697209                 UA                     19977
# 27556637                 9E                     20363
# ...

# %%
random_seed = 42
# You can change 'random_seed' to any integer for different random samples

# Take a random 5% sample of the data
sampled_dataset1 = sampled_dataset.sample(frac=0.01, random_state=random_seed)

# Print the sampled dataset
sampled_dataset1
# Out:
#           Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 1315458   2018        3      7          14          6  2018-07-14
# 15507572  2020        2      6          27          6  2020-06-27
# 1947015   2018        2      5           8          2  2018-05-08
# 16500915  2020        1      1          12          7  2020-01-12
# 26608427  2021        3      8          15          7  2021-08-15
# ...        ...      ...    ...         ...        ...         ...
# 17491963  2020        1      3          17          2  2020-03-17
# 28277403  2022        2      5          13          5  2022-05-13
# 21772809  2021        2      5          13          4  2021-05-13
# 20708240  2021        2      6           6          7  2021-06-06
# 30066444  2022        1      3          29          2  2022-03-29
#
#          Operating_Airline   DOT_ID_Operating_Airline  \
# 1315458                  OO                     20304
# 15507572                 MQ                     20398
# ...
